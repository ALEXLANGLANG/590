# %% [markdown]
# # Training ReNet-5 on CIFAR-10

# %% [markdown]
# ### Step 0 Setting up ReNet model

# %%
import argparse
import os, sys
import time
import datetime

# Import pytorch dependencies
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
from tqdm import tqdm_notebook as tqdm

# %%
import math
# Create the neural network module: ResNet20
# I used LeNet5 to name ResNet20 in the following code
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        #Layer1 - 7
        self.conv1 = nn.Conv2d(3, 16, 3, padding = 1)
        self.conv1_1 = nn.Conv2d(16, 16, 3,padding = 1) #Layer 2-7
        self.conv1_2 = nn.Conv2d(16, 16, 3,padding = 1) #Layer 2-7
        self.conv1_3 = nn.Conv2d(16, 16, 3,padding = 1) #Layer 2-7
        self.conv1_4 = nn.Conv2d(16, 16, 3,padding = 1) #Layer 2-7
        self.conv1_5 = nn.Conv2d(16, 16, 3,padding = 1) #Layer 2-7
        self.conv1_6 = nn.Conv2d(16, 16, 3,padding = 1) #Layer 2-7
        
        self.bn1 = nn.BatchNorm2d(16)
        self.bn1_1 = nn.BatchNorm2d(16)
        self.bn1_2 = nn.BatchNorm2d(16)
        self.bn1_3 = nn.BatchNorm2d(16)
        self.bn1_4 = nn.BatchNorm2d(16)
        self.bn1_5 = nn.BatchNorm2d(16)
        self.bn1_6 = nn.BatchNorm2d(16)
        
        #Layer 8 - 13
        self.conv2 = nn.Conv2d(16, 32, 3,padding = 1,stride = 2)
        self.conv2_1 = nn.Conv2d(32, 32, 3,padding = 1)#Layer 9-13
        self.conv2_2 = nn.Conv2d(32, 32, 3,padding = 1)#Layer 9-13
        self.conv2_3 = nn.Conv2d(32, 32, 3,padding = 1)#Layer 9-13
        self.conv2_4 = nn.Conv2d(32, 32, 3,padding = 1)#Layer 9-13
        self.conv2_5 = nn.Conv2d(32, 32, 3,padding = 1)#Layer 9-13
        
#         self.con2_1x1 = nn.Conv2d(16, 32, 1,stride = 2)
        self.bn2_1x1 = nn.BatchNorm2d(32)
        
        self.bn2 = nn.BatchNorm2d(32)
        self.bn2_1 = nn.BatchNorm2d(32)
        self.bn2_2 = nn.BatchNorm2d(32)
        self.bn2_3 = nn.BatchNorm2d(32)
        self.bn2_4 = nn.BatchNorm2d(32)
        self.bn2_5 = nn.BatchNorm2d(32)

        
        #Layer 14 - 19
        self.conv3 = nn.Conv2d(32, 64, 3,padding = 1,stride = 2)
        self.conv3_1 = nn.Conv2d(64, 64, 3,padding = 1) #Layer 15-19
        self.conv3_2 = nn.Conv2d(64, 64, 3,padding = 1) #Layer 15-19
        self.conv3_3 = nn.Conv2d(64, 64, 3,padding = 1) #Layer 15-19
        self.conv3_4 = nn.Conv2d(64, 64, 3,padding = 1) #Layer 15-19
        self.conv3_5 = nn.Conv2d(64, 64, 3,padding = 1) #Layer 15-19
        
#         self.con3_1x1 = nn.Conv2d(32, 64, 1,stride = 2)
        self.bn3_1x1 = nn.BatchNorm2d(64)
        
        self.bn3 = nn.BatchNorm2d(64)
        self.bn3_1 = nn.BatchNorm2d(64)
        self.bn3_2 = nn.BatchNorm2d(64)
        self.bn3_3 = nn.BatchNorm2d(64)
        self.bn3_4 = nn.BatchNorm2d(64)
        self.bn3_5 = nn.BatchNorm2d(64)
        
        #Layer 20
        self.fc = nn.Linear(64,10)
#         self._initialize_weights()
        
    def forward(self, x):
        #Layer1
        out1 = F.relu(self.bn1(self.conv1(x)))
        #Layer2-7
        out2 =  F.relu(self.bn1_1(self.conv1_1(out1)))
        out3 =  F.relu(self.bn1_2(self.conv1_2(out2)) + out1)
        out4 =  F.relu(self.bn1_3(self.conv1_3(out3)))
        out5 =  F.relu(self.bn1_4(self.conv1_4(out4) + out3))       
        out6 =  F.relu(self.bn1_5(self.conv1_5(out5))) 
        out7 =  F.relu(self.bn1_6(self.conv1_6(out6)) + out5 ) 
        
        #Layer 8-13
        out8 =  F.relu(self.bn2(self.conv2(out7)))
        re_dis1 = nn.Conv2d(16,32,1,stride = 2)
        re_dis1.to('cuda')
        re_dis1.weight.data.fill_(1)
        out9 =  F.relu(self.bn2_1(self.conv2_1(out8)) + self.bn2_1x1(re_dis1(out7))) # Should reduce dimension of out7 
        out10 =  F.relu(self.bn2_2(self.conv2_2(out9)))
        out11 =  F.relu(self.bn2_3(self.conv2_3(out10)) + out9)            
        out12 =  F.relu(self.bn2_4(self.conv2_4(out11)))
        out13 =  F.relu(self.bn2_5(self.conv2_5(out12)) + out11)    
                       
        #Layer 14-19
        out14 =  F.relu(self.bn3(self.conv3(out13))) 
        re_dis2 = nn.Conv2d(32, 64, 1,stride = 2)
        re_dis2.to('cuda')
        re_dis2.weight.data.fill_(1)
        out15 =  F.relu(self.bn3_1(self.conv3_1(out14)) + self.bn3_1x1(re_dis2(out13))) # Should reduce dimension of out13               
        out16 =  F.relu(self.bn3_2(self.conv3_2(out15)))
        out17 =  F.relu(self.bn3_3(self.conv3_3(out16)) + out15)
        out18 =  F.relu(self.bn3_4(self.conv3_4(out17)))
        out19 =  F.relu(self.bn3_5(self.conv3_5(out18)) + out17)               
        
        #Final layer              
        out = F.avg_pool2d(out19, out19.size()[3])
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out

#     def _initialize_weights(self):
#         for m in self.modules():
#             if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
#                 nn.init.kaiming_normal_(m.weight)
    '''
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * (m.in_channels + m.out_channels)
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                n = m.weight.size(1)
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_() 
                '''

# %% [markdown]
# ### Step 1: Setting up preprocessing functions.
# Preprocessing is very important because it prepares your data for proceeding training steps.
# Write functions to load dataset and preprocess the incoming data. We recommend that the preprocess scheme \textbf{must} include normalize, standardization, batch shuffling to make sure the training
# process goes smoothly. The preprocess scheme may also contain some data augmentation methods
# (e.g., random crop, random flip, etc.).
#
# Reference value for mean/std:
#
# **mean(RGB-format): (0.4914, 0.4822, 0.4465)**
#
# **std(RGB-format): (0.2023, 0.1994, 0.2010)**

# %%
# Specify preprocessing function.
# Reference mean/std value for 
transform_train  = transforms.Compose([
        transforms.RandomCrop(size = 32,padding = 4),
        transforms.RandomHorizontalFlip(p = 0.6),
        transforms.ToTensor(), # convert input into tensor 
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

transform_val = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

# %%
#Verify the implementation of LeNet-5 Model

# GPU check                
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device =='cuda':
    print("Run on GPU...")
else:
    print("Run on CPU...")

# Model Definition  
net = LeNet5()
net = net.to(device)

# Test forward pass
data = torch.randn(5,3,32,32)
data = data.to(device)
# Forward pass "data" through "net" to get output "out" 
out =  net(data) #Your code here
# Check output shape
assert(out.detach().cpu().numpy().shape == (5,10))
print("Forward pass successful")
# Out:
# Run on GPU...
# Forward pass successful

# %% [markdown]
# ### Step 2: Setting up data I/O
# Data I/O reads data from the dataset and prepares it for further procedures. Note that you have to link transformation with data I/O so that these operations can be interleaved. Thus, the training process can be more efficient.

# %%
# You cannot change this line.
from tools.dataloader import CIFAR10
# Call the dataset Loader
DATAROOT = "./data"
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100
trainset = CIFAR10(root=DATAROOT, train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=TRAIN_BATCH_SIZE, shuffle=True, num_workers=4)
valset = CIFAR10(root=DATAROOT, train=False, download=True, transform=transform_val)
valloader = torch.utils.data.DataLoader(valset, batch_size=VAL_BATCH_SIZE, shuffle=False, num_workers=4)
# Out:
# Using downloaded and verified file: ./data/cifar10_trainval_F20.zip
# Extracting ./data/cifar10_trainval_F20.zip to ./data
# Files already downloaded and verified
# Training dataset has 45000 examples!
# Using downloaded and verified file: ./data/cifar10_trainval_F20.zip
# Extracting ./data/cifar10_trainval_F20.zip to ./data
# Files already downloaded and verified
# Validation dataset has 5000 examples!

# %% [markdown]
# ### Step 3: Instantialize your LeNet-5 model and deploy it to GPU devices.
# You may want to deploy your model to GPU device for efficient training. Please assign your model to GPU if possible. If you are training on a machine without GPUs, please deploy your model to CPUs.

# %%
# Specify the device for computation
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = LeNet5()
net = net.to(device)
if device =='cuda':
    print("Train on GPU...")
else:
    print("Train on CPU...")
# Out:
# Train on GPU...

# %% [markdown]
# ### Hyperparameter settings
# Hyperparameters are quite crucial in determining the performance of our model. The default hyperparameter settings are sufficient for a decent result. You may tune them wisely and carefully for better results.

# %%
# Initial learning rate
INITIAL_LR = 0.1
# Momentum for optimizer.
MOMENTUM = 0.9
# Regularization
REG = 1e-4
# Total number of training epochs
EPOCHS = 200
# Learning rate decay policy.
DECAY_EPOCHS = 50
DECAY = 0.1

# %% [markdown]
# ### Handling weights load/save protocols.
# This handles the weight loading/saving protocols.You may be able to load from checkpoints.

# %%
CHECKPOINT_PATH = "./saved_model"
# FLAG for loading the pretrained model
TRAIN_FROM_SCRATCH = True
# Code for loading checkpoint and recover epoch id.
CKPT_PATH = "./saved_model/model.h5"
def get_checkpoint(ckpt_path):
    try:
        ckpt = torch.load(ckpt_path)
    except Exception as e:
        print(e)
        return None
    return ckpt

ckpt = get_checkpoint(CKPT_PATH)
if ckpt is None or TRAIN_FROM_SCRATCH:
    if not TRAIN_FROM_SCRATCH:
        print("Checkpoint not found.")
    print("Training from scratch ...")
    start_epoch = 0
    current_learning_rate = INITIAL_LR
else:
    print("Successfully loaded checkpoint: %s" %CKPT_PATH)
    net.load_state_dict(ckpt['net'])
    start_epoch = ckpt['epoch'] + 1
    current_learning_rate = ckpt['lr']
    print("Starting from epoch %d " %start_epoch)

print("Starting from learning rate %f:" %current_learning_rate)
# Out:
# Training from scratch ...
# Starting from learning rate 0.100000:

# %% [markdown]
# ### Step 4 Setting up loss functions and Optimizers
# Loss function is your objective to train the neural networks. Typically, we use multi-class cross entropy as objectives for classification models (e.g., CIFAR-10, MNIST). In this homework, we use SGD optimizer with momentum as our optimizer. You need to formulate the cross-entropy loss function in PyTorch.
# You should also specify a PyTorch Optimizer to optimize this loss function.

# %%
# Create loss function and specify regularization
criterion = nn.CrossEntropyLoss()
# Add optimizer
optimizer = optim.SGD(params=net.parameters(), lr=current_learning_rate, momentum=MOMENTUM, weight_decay=REG, nesterov=False)

# %% [markdown]
# ### Step 5: Start the training process.
# Congratulations! You have completed all of the previous steps and it is time to train our neural network.
# Training a neural network usually composes the following 3 parts:
#
# **i) Get a batch of data from the dataloader and copy it to your device (GPU)**
#
# **ii) Do a forward pass to get the output logits from the neural network. Compute the forward loss.**
#
# **iii) Do a backward pass (back-propagation) to compute gradients of all weights with respect to the loss.**
#
# You will also need to compute accuracy within all these parts to justify that your model is doing well on the dataset.

# %%
# Start the training/validation process
# The process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
list_train =[]
list_val =[]
global_step = 0
best_val_acc = 0


for i in range(start_epoch, EPOCHS):
#     print(datetime.datetime.now())
    # Switch to train mode
    net.train()
    print("Epoch %d:" %i)

    total_examples = 0
    correct_examples = 0

    train_loss = 0
    train_acc = 0
    
    # Train the training dataset for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        # Copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)
        # Zero the gradient
        optimizer.zero_grad()
        # Generate output
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        if (batch_idx == 0) & (i == start_epoch):
            print("INITIAL LOSS before traning: %.4f" %loss)
        # Now backward loss
        loss.backward()
        # Apply gradient
        optimizer.step()
        # Calculate predicted labels
        _, predicted = outputs.max(1)
        total_examples += predicted.size(0)
        correct_examples += predicted.eq(targets).sum().item()
        train_loss += loss
        global_step += 1
                
    avg_loss = train_loss / (batch_idx + 1)
    avg_acc = correct_examples / total_examples
    list_train.append(avg_acc)
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))
#     print(datetime.datetime.now())
    # Validate on the validation dataset
#     print("Validation...")
    total_examples = 0
    correct_examples = 0
    
    net.eval()

    val_loss = 0
    val_acc = 0
    # Disable gradient during validation
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(valloader):
            # Copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)
            # Zero the gradient
            optimizer.zero_grad()
            # Generate output from the DNN.
            outputs = net(inputs)
            loss = criterion(outputs, targets)            
            # Calculate predicted labels
            _, predicted = outputs.max(1)
            total_examples += predicted.size(0)
            correct_examples += predicted.eq(targets).sum().item()
            val_loss += loss

    avg_loss = val_loss / len(valloader)
    avg_acc = correct_examples / total_examples

    list_val.append(avg_acc)
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    if(avg_acc > 0.92):
        break;
        
    # Handle the learning rate scheduler.
    if i % DECAY_EPOCHS == 0 and i != 0:
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
#         print("Current learning rate has decayed to %f" %current_learning_rate)
    
    # Save for checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_PATH):
            os.makedirs(CHECKPOINT_PATH)
        print("Saving ...")
        state = {'net': net.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_PATH, 'model.h5'))

print("Optimization finished.")
# Out:
# Epoch 0:
# INITIAL LOSS before traning: 2.5546
# Training loss: 1.8612, Training accuracy: 0.2870
# Validation loss: 1.8066, Validation accuracy: 0.3472
# Saving ...
# Epoch 1:
# Training loss: 1.4880, Training accuracy: 0.4487
# Validation loss: 1.5314, Validation accuracy: 0.4792
# Saving ...
# Epoch 2:
# Training loss: 1.1816, Training accuracy: 0.5744
# Validation loss: 1.2187, Validation accuracy: 0.5700
# Saving ...
# Epoch 3:
# Training loss: 0.9836, Training accuracy: 0.6461
# Validation loss: 1.0179, Validation accuracy: 0.6500
# Saving ...
# Epoch 4:
# Training loss: 0.8603, Training accuracy: 0.6950
# Validation loss: 1.0390, Validation accuracy: 0.6482
# Epoch 5:
# Training loss: 0.7487, Training accuracy: 0.7360
# Validation loss: 0.7282, Validation accuracy: 0.7472
# Saving ...
# Epoch 6:
# Training loss: 0.6642, Training accuracy: 0.7682
# Validation loss: 0.7357, Validation accuracy: 0.7568
# Saving ...
# Epoch 7:
# Training loss: 0.6107, Training accuracy: 0.7862
# ...

# %%
max(list_val)
# Out:
# 0.9126

# %%
from tools.dataloader_test import CIFAR10
import numpy as np
import pandas as pd
# Call the dataset Loader
DATAROOT = "./data"
TEST_BATCH_SIZE = 1
testset = CIFAR10(root=DATAROOT, train=False, download=True, transform=transform_val)
testloader = torch.utils.data.DataLoader(testset, batch_size=TEST_BATCH_SIZE, shuffle=False, num_workers=4)
# Out:
# Using downloaded and verified file: ./data/cifar10_test_F20.zip
# Extracting ./data/cifar10_test_F20.zip to ./data
# Files already downloaded and verified
# Testing dataset has 10000 examples!

# %%
df = np.zeros(shape=(10000,2))
for batch_idx, (inputs,outputs ) in enumerate(testloader):
    inputs = inputs.to(device) 
    out = net(inputs)
    out = out.detach().cpu().numpy()
    y_pred = np.argmax(out)
    df[batch_idx] = np.array([batch_idx,y_pred])

# %%
df = df.astype('int')
dataset = pd.DataFrame({'Id': df[:, 0], 'Label': df[:, 1]})
dataset.to_csv('predictions.csv',index=False)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10,6))

plt.title("Normal vs Default Weights Initialization")
# plt.plot(range(start_epoch, EPOCHS), list_val, '-o',label = "val")
plt.plot(range(0, EPOCHS), list_val, '-o', label = "validation with Default")
plt.plot(range(0, EPOCHS), list_train, '-o', label = "train with Default")
plt.legend(loc="lower right")
plt.xlabel('EPOCHS')
plt.ylabel('Accuracy')


# # plt.plot(range(start_epoch, EPOCHS), list_val, '-o',label = "val")
# plt.plot(range(0, EPOCHS), list_val_k, '-o', label = "validation with Normal")
# plt.plot(range(0, EPOCHS), list_train_k, '-o', label = "train with Normal")
# plt.legend(loc="lower right")
# plt.xlabel('EPOCHS')
# plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
res1_tr=list_train 
res1_val = list_val

# %% [markdown]
# ### Bonus Try to initialize the weights with Kaiming- Normal

# %%
# Specify the device for computation
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = LeNet5()
net = net.to(device)
if device =='cuda':
    print("Train on GPU...")
else:
    print("Train on CPU...")

# %%
# Set model weights with kaiming normalization
nn.init.kaiming_normal_(net.conv1.weight)
nn.init.kaiming_normal_(net.conv2.weight)
nn.init.kaiming_normal_(net.fc1.weight)
nn.init.kaiming_normal_(net.fc2.weight)
nn.init.kaiming_normal_(net.fc3.weight)
avoidprint = 1

# %%
# Initial learning rate
INITIAL_LR = 0.01
# Momentum for optimizer.
MOMENTUM = 0.9
# Regularization
REG = 1e-4
# Total number of training epochs
EPOCHS = 30
# Learning rate decay policy.
DECAY_EPOCHS = 2
DECAY = 1.00
# Create loss function and specify regularization
criterion = nn.CrossEntropyLoss()
# Add optimizer
optimizer = optim.SGD(params=net.parameters(), lr=current_learning_rate, momentum=MOMENTUM, weight_decay=REG, nesterov=False)

# %%
# # Start the training/validation process
# # The process should take about 5 minutes on a GTX 1070-Ti
# # if the code is written efficiently.
# list_train_k =[]
# list_val_k =[]
# global_step = 0
# best_val_acc = 0

# for i in range(start_epoch, EPOCHS):
#     print(datetime.datetime.now())
#     # Switch to train mode
#     net.train()
#     print("Epoch %d:" %i)

#     total_examples = 0
#     correct_examples = 0

#     train_loss = 0
#     train_acc = 0
    
#     # Train the training dataset for 1 epoch.
#     for batch_idx, (inputs, targets) in enumerate(trainloader):
#         # Copy inputs to device
#         inputs = inputs.to(device)
#         targets = targets.to(device)
#         # Zero the gradient
#         optimizer.zero_grad()
#         # Generate output 
#         outputs = net(inputs)
#         loss = criterion(outputs, targets)
#         # Now backward loss
#         loss.backward()
#         # Apply gradient
#         optimizer.step()
#         # Calculate predicted labels
#         _, predicted = outputs.max(1)
#         total_examples += predicted.size(0)
#         correct_examples += predicted.eq(targets).sum().item()
#         train_loss += loss
#         global_step += 1
                
#     avg_loss = train_loss / (batch_idx + 1)
#     avg_acc = correct_examples / total_examples
#     list_train_k.append(avg_acc)
# #     print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))
# #     print(datetime.datetime.now())
#     # Validate on the validation dataset
# #     print("Validation...")
#     total_examples = 0
#     correct_examples = 0
    
#     net.eval()

#     val_loss = 0
#     val_acc = 0
#     # Disable gradient during validation
#     with torch.no_grad():
#         for batch_idx, (inputs, targets) in enumerate(valloader):
#             # Copy inputs to device
#             inputs = inputs.to(device)
#             targets = targets.to(device)
#             # Zero the gradient
#             optimizer.zero_grad()
#             # Generate output from the DNN.
#             outputs = net(inputs)
#             loss = criterion(outputs, targets)            
#             # Calculate predicted labels
#             _, predicted = outputs.max(1)
#             total_examples += predicted.size(0)
#             correct_examples += predicted.eq(targets).sum().item()
#             val_loss += loss

#     avg_loss = val_loss / len(valloader)
#     avg_acc = correct_examples / total_examples
#     list_val_k.append(avg_acc)
# #     print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))

#     # Handle the learning rate scheduler.
#     if i % DECAY_EPOCHS == 0 and i != 0:
#         current_learning_rate = current_learning_rate * DECAY
#         for param_group in optimizer.param_groups:
#             param_group['lr'] = current_learning_rate
# #         print("Current learning rate has decayed to %f" %current_learning_rate)
    
#     # Save for checkpoint
#     if avg_acc > best_val_acc:
#         best_val_acc = avg_acc
#         if not os.path.exists(CHECKPOINT_PATH):
#             os.makedirs(CHECKPOINT_PATH)
# #         print("Saving ...")
#         state = {'net': net.state_dict(),
#                  'epoch': i,
#                  'lr': current_learning_rate}
#         torch.save(state, os.path.join(CHECKPOINT_PATH, 'model.h5'))

# print("Optimization finished.")
