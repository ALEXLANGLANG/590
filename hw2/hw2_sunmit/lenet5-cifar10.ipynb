# %% [markdown]
# # Training LeNet-5 on CIFAR-10
# In this notebook, we will try to deploy the famous LeNet-5 to solve a simple image classification task, the CIFAR-10. CIFAR-10 is composed of 60K images from 10 categories. After splitting the dataset, we have 45K/5K/10K images for train/valiation/test dataset.
# In this notebook, only the labels of training/validation dataset is visible to you, so you can use the training and validation data to tune your model. After you submitted your model, your final grade will be determined on the model performance on the holdout test dataset.

# %% [markdown]
# ### Step 0 Setting up LeNet-5 model
# As you have set up the LeNet-5 model in Homework 1, we will just move the implementation of LeNet-5 model here, so you can use it for this homework.

# %%
import argparse
import os, sys
import time
import datetime

# Import pytorch dependencies
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
from tqdm import tqdm_notebook as tqdm

# %%
import math
# Create the neural network module: LeNet-5
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1   = nn.Linear(16*5*5, 120)
        self.fc2   = nn.Linear(120, 84)
        self.fc3   = nn.Linear(84, 10)
        self._initialize_weights() # ### Bonus Try to initialize the weights with Kaiming- Normal

    def forward(self, x):
        
        out = F.relu(self.conv1(x))
        out = F.max_pool2d(out, 2)
        out = F.relu(self.conv2(out))
        out = F.max_pool2d(out, 2)
        out = out.view(out.size(0), -1)
        out = F.relu(self.fc1(out))
        out = F.relu(self.fc2(out))
        out = self.fc3(out)
        return out

    ### Bonus Try to initialize the weights with Kaiming- Normal
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight)
    """
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * (m.in_channels + m.out_channels)
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                n = m.weight.size(1)
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_() """

# %% [markdown]
# ### Step 1: Setting up preprocessing functions.
# Preprocessing is very important because it prepares your data for proceeding training steps.
# Write functions to load dataset and preprocess the incoming data. We recommend that the preprocess scheme \textbf{must} include normalize, standardization, batch shuffling to make sure the training
# process goes smoothly. The preprocess scheme may also contain some data augmentation methods
# (e.g., random crop, random flip, etc.).
#
# Reference value for mean/std:
#
# **mean(RGB-format): (0.4914, 0.4822, 0.4465)**
#
# **std(RGB-format): (0.2023, 0.1994, 0.2010)**

# %%
# Specify preprocessing function.
# Reference mean/std value for 
transform_train  = transforms.Compose([
        transforms.ToTensor(), # convert input into tensor 
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

transform_val = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

# %%
#Verify the implementation of LeNet-5 Model

# GPU check                
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device =='cuda':
    print("Run on GPU...")
else:
    print("Run on CPU...")

# Model Definition  
net = LeNet5()
net = net.to(device)

# Test forward pass
data = torch.randn(5,3,32,32)
data = data.to(device)
# Forward pass "data" through "net" to get output "out" 
out =  net(data) #Your code here
# Check output shape
assert(out.detach().cpu().numpy().shape == (5,10))
print("Forward pass successful")
# Out:
# Run on GPU...
# Forward pass successful

# %% [markdown]
# ### Step 2: Setting up data I/O
# Data I/O reads data from the dataset and prepares it for further procedures. Note that you have to link transformation with data I/O so that these operations can be interleaved. Thus, the training process can be more efficient.

# %%
# You cannot change this line.
from tools.dataloader import CIFAR10
# Call the dataset Loader
DATAROOT = "./data"
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100
trainset = CIFAR10(root=DATAROOT, train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=TRAIN_BATCH_SIZE, shuffle=True, num_workers=4)
valset = CIFAR10(root=DATAROOT, train=False, download=True, transform=transform_val)
valloader = torch.utils.data.DataLoader(valset, batch_size=VAL_BATCH_SIZE, shuffle=False, num_workers=4)
# Out:
# Using downloaded and verified file: ./data/cifar10_trainval_F20.zip
# Extracting ./data/cifar10_trainval_F20.zip to ./data
# Files already downloaded and verified
# Training dataset has 45000 examples!
# Using downloaded and verified file: ./data/cifar10_trainval_F20.zip
# Extracting ./data/cifar10_trainval_F20.zip to ./data
# Files already downloaded and verified
# Validation dataset has 5000 examples!

# %% [markdown]
# ### Step 3: Instantialize your LeNet-5 model and deploy it to GPU devices.
# You may want to deploy your model to GPU device for efficient training. Please assign your model to GPU if possible. If you are training on a machine without GPUs, please deploy your model to CPUs.

# %%
# Specify the device for computation
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = LeNet5()
net = net.to(device)
if device =='cuda':
    print("Train on GPU...")
else:
    print("Train on CPU...")
# Out:
# Train on GPU...

# %% [markdown]
# ### Hyperparameter settings
# Hyperparameters are quite crucial in determining the performance of our model. The default hyperparameter settings are sufficient for a decent result. You may tune them wisely and carefully for better results.

# %%
# Initial learning rate
INITIAL_LR = 0.01
# Momentum for optimizer.
MOMENTUM = 0.9
# Regularization
REG = 1e-4
# Total number of training epochs
EPOCHS = 30
# Learning rate decay policy.
DECAY_EPOCHS = 2
DECAY = 1.00

# %% [markdown]
# ### Handling weights load/save protocols.
# This handles the weight loading/saving protocols.You may be able to load from checkpoints.

# %%
CHECKPOINT_PATH = "./saved_model"
# FLAG for loading the pretrained model
TRAIN_FROM_SCRATCH = True
# Code for loading checkpoint and recover epoch id.
CKPT_PATH = "./saved_model/model.h5"
def get_checkpoint(ckpt_path):
    try:
        ckpt = torch.load(ckpt_path)
    except Exception as e:
        print(e)
        return None
    return ckpt

ckpt = get_checkpoint(CKPT_PATH)
if ckpt is None or TRAIN_FROM_SCRATCH:
    if not TRAIN_FROM_SCRATCH:
        print("Checkpoint not found.")
    print("Training from scratch ...")
    start_epoch = 0
    current_learning_rate = INITIAL_LR
else:
    print("Successfully loaded checkpoint: %s" %CKPT_PATH)
    net.load_state_dict(ckpt['net'])
    start_epoch = ckpt['epoch'] + 1
    current_learning_rate = ckpt['lr']
    print("Starting from epoch %d " %start_epoch)

print("Starting from learning rate %f:" %current_learning_rate)
# Out:
# Training from scratch ...
# Starting from learning rate 0.010000:

# %% [markdown]
# ### Step 4 Setting up loss functions and Optimizers
# Loss function is your objective to train the neural networks. Typically, we use multi-class cross entropy as objectives for classification models (e.g., CIFAR-10, MNIST). In this homework, we use SGD optimizer with momentum as our optimizer. You need to formulate the cross-entropy loss function in PyTorch.
# You should also specify a PyTorch Optimizer to optimize this loss function.

# %%
# Create loss function and specify regularization
criterion = nn.CrossEntropyLoss()
# Add optimizer
optimizer = optim.SGD(params=net.parameters(), lr=current_learning_rate, momentum=MOMENTUM, weight_decay=REG, nesterov=False)

# %% [markdown]
# ### Step 5: Start the training process.
# Congratulations! You have completed all of the previous steps and it is time to train our neural network.
# Training a neural network usually composes the following 3 parts:
#
# **i) Get a batch of data from the dataloader and copy it to your device (GPU)**
#
# **ii) Do a forward pass to get the output logits from the neural network. Compute the forward loss.**
#
# **iii) Do a backward pass (back-propagation) to compute gradients of all weights with respect to the loss.**
#
# You will also need to compute accuracy within all these parts to justify that your model is doing well on the dataset.

# %%
# Start the training/validation process
# The process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
list_train =[]
list_val =[]
global_step = 0
best_val_acc = 0

for i in range(start_epoch, EPOCHS):
#     print(datetime.datetime.now())
    # Switch to train mode
    net.train()
    print("Epoch %d:" %i)

    total_examples = 0
    correct_examples = 0

    train_loss = 0
    train_acc = 0
    
    # Train the training dataset for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        # Copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)
        # Zero the gradient
        optimizer.zero_grad()
        # Generate output
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        if (batch_idx == 0) & (i == start_epoch):
            print("INITIAL LOSS before traning: %.4f" %loss)
        # Now backward loss
        loss.backward()
        # Apply gradient
        optimizer.step()
        # Calculate predicted labels
        _, predicted = outputs.max(1)
        total_examples += predicted.size(0)
        correct_examples += predicted.eq(targets).sum().item()
        train_loss += loss
        global_step += 1
                
    avg_loss = train_loss / (batch_idx + 1)
    avg_acc = correct_examples / total_examples
    list_train.append(avg_acc)
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))
#     print(datetime.datetime.now())
    # Validate on the validation dataset
    print("Validation...")
    total_examples = 0
    correct_examples = 0
    
    net.eval()

    val_loss = 0
    val_acc = 0
    # Disable gradient during validation
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(valloader):
            # Copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)
            # Zero the gradient
            optimizer.zero_grad()
            # Generate output from the DNN.
            outputs = net(inputs)
            loss = criterion(outputs, targets)            
            # Calculate predicted labels
            _, predicted = outputs.max(1)
            total_examples += predicted.size(0)
            correct_examples += predicted.eq(targets).sum().item()
            val_loss += loss

    avg_loss = val_loss / len(valloader)
    avg_acc = correct_examples / total_examples
    list_val.append(avg_acc)
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))

    # Handle the learning rate scheduler.
    if i % DECAY_EPOCHS == 0 and i != 0:
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)
    
    # Save for checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_PATH):
            os.makedirs(CHECKPOINT_PATH)
        print("Saving ...")
        state = {'net': net.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_PATH, 'model.h5'))

print("Optimization finished.")
# Out:
# Epoch 0:
# INITIAL LOSS before traning: 3.5097
# Training loss: 1.7356, Training accuracy: 0.3621
# Validation...
# Validation loss: 1.5449, Validation accuracy: 0.4316
# Saving ...
# Epoch 1:
# Training loss: 1.4593, Training accuracy: 0.4694
# Validation...
# Validation loss: 1.4157, Validation accuracy: 0.4932
# Saving ...
# Epoch 2:
# Training loss: 1.3408, Training accuracy: 0.5177
# Validation...
# Validation loss: 1.3584, Validation accuracy: 0.5116
# Current learning rate has decayed to 0.010000
# Saving ...
# Epoch 3:
# Training loss: 1.2581, Training accuracy: 0.5486
# Validation...
# Validation loss: 1.2943, Validation accuracy: 0.5444
# Saving ...
# Epoch 4:
# Training loss: 1.1977, Training accuracy: 0.5722
# Validation...
# Validation loss: 1.3023, Validation accuracy: 0.5374
# Current learning rate has decayed to 0.010000
# Epoch 5:
# Training loss: 1.1369, Training accuracy: 0.5949
# Validation...
# Validation loss: 1.2136, Validation accuracy: 0.5746
# Saving ...
# Epoch 6:
# Training loss: 1.0982, Training accuracy: 0.6109
# Validation...
# Validation loss: 1.2121, Validation accuracy: 0.5750
# Current learning rate has decayed to 0.010000
# Saving ...
# Epoch 7:
# Training loss: 1.0672, Training accuracy: 0.6214
# Validation...
# Validation loss: 1.2230, Validation accuracy: 0.5712
# Epoch 8:
# Training loss: 1.0229, Training accuracy: 0.6369
# Validation...
# Validation loss: 1.1808, Validation accuracy: 0.5982
# Current learning rate has decayed to 0.010000
# Saving ...
# Epoch 9:
# Training loss: 0.9886, Training accuracy: 0.6484
# Validation...
# Validation loss: 1.1791, Validation accuracy: 0.5860
# Epoch 10:
# Training loss: 0.9647, Training accuracy: 0.6578
# Validation...
# Validation loss: 1.2218, Validation accuracy: 0.5788
# Current learning rate has decayed to 0.010000
# Epoch 11:
# Training loss: 0.9320, Training accuracy: 0.6685
# Validation...
# Validation loss: 1.2603, Validation accuracy: 0.5798
# Epoch 12:
# Training loss: 0.9020, Training accuracy: 0.6789
# Validation...
# Validation loss: 1.2330, Validation accuracy: 0.5854
# Current learning rate has decayed to 0.010000
# Epoch 13:
# Training loss: 0.8757, Training accuracy: 0.6878
# Validation...
# Validation loss: 1.1908, Validation accuracy: 0.6006
# Saving ...
# Epoch 14:
# Training loss: 0.8498, Training accuracy: 0.6985
# Validation...
# Validation loss: 1.1732, Validation accuracy: 0.6088
# Current learning rate has decayed to 0.010000
# Saving ...
# Epoch 15:
# Training loss: 0.8291, Training accuracy: 0.7056
# Validation...
# Validation loss: 1.1883, Validation accuracy: 0.6074
# Epoch 16:
# Training loss: 0.8070, Training accuracy: 0.7131
# Validation...
# Validation loss: 1.2487, Validation accuracy: 0.5912
# Current learning rate has decayed to 0.010000
# Epoch 17:
# Training loss: 0.7784, Training accuracy: 0.7215
# Validation...
# Validation loss: 1.2585, Validation accuracy: 0.5908
# Epoch 18:
# Training loss: 0.7635, Training accuracy: 0.7269
# Validation...
# Validation loss: 1.2556, Validation accuracy: 0.5980
# Current learning rate has decayed to 0.010000
# Epoch 19:
# Training loss: 0.7497, Training accuracy: 0.7322
# Validation...
# Validation loss: 1.2727, Validation accuracy: 0.5996
# Epoch 20:
# Training loss: 0.7197, Training accuracy: 0.7415
# Validation...
# Validation loss: 1.3641, Validation accuracy: 0.5810
# Current learning rate has decayed to 0.010000
# Epoch 21:
# Training loss: 0.7039, Training accuracy: 0.7474
# Validation...
# Validation loss: 1.2583, Validation accuracy: 0.6036
# Epoch 22:
# Training loss: 0.6806, Training accuracy: 0.7551
# Validation...
# Validation loss: 1.3225, Validation accuracy: 0.6082
# Current learning rate has decayed to 0.010000
# Epoch 23:
# Training loss: 0.6673, Training accuracy: 0.7580
# Validation...
# Validation loss: 1.3379, Validation accuracy: 0.5932
# Epoch 24:
# Training loss: 0.6504, Training accuracy: 0.7648
# Validation...
# Validation loss: 1.3984, Validation accuracy: 0.6014
# Current learning rate has decayed to 0.010000
# Epoch 25:
# Training loss: 0.6401, Training accuracy: 0.7693
# Validation...
# Validation loss: 1.3726, Validation accuracy: 0.5954
# Epoch 26:
# Training loss: 0.6202, Training accuracy: 0.7756
# Validation...
# Validation loss: 1.4133, Validation accuracy: 0.5864
# Current learning rate has decayed to 0.010000
# Epoch 27:
# Training loss: 0.5986, Training accuracy: 0.7851
# Validation...
# Validation loss: 1.4655, Validation accuracy: 0.5940
# Epoch 28:
# Training loss: 0.5963, Training accuracy: 0.7847
# Validation...
# Validation loss: 1.4723, Validation accuracy: 0.5904
# Current learning rate has decayed to 0.010000
# Epoch 29:
# Training loss: 0.5697, Training accuracy: 0.7961
# Validation...
# Validation loss: 1.5045, Validation accuracy: 0.5906
# Optimization finished.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10,6))

plt.title("Normal vs Default Weights Initialization")
# plt.plot(range(start_epoch, EPOCHS), list_val, '-o',label = "val")
plt.plot(range(0, EPOCHS), list_val[30:], '-o', label = "validation with Default")
plt.plot(range(0, EPOCHS), list_train[30:], '-o', label = "train with Default")
plt.legend(loc="lower right")
plt.xlabel('EPOCHS')
plt.ylabel('Accuracy')


# plt.plot(range(start_epoch, EPOCHS), list_val, '-o',label = "val")
plt.plot(range(0, EPOCHS), list_val[:30], '-o', label = "validation with Normal")
plt.plot(range(0, EPOCHS), list_train[:30], '-o', label = "train with Normal")
plt.legend(loc="lower right")
plt.xlabel('EPOCHS')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
import math
# Create the neural network module: LeNet-5
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1   = nn.Linear(16*5*5, 120)
        self.fc2   = nn.Linear(120, 84)
        self.fc3   = nn.Linear(84, 10)
#         self._initialize_weights() # ### Bonus Try to initialize the weights with Kaiming- Normal

    def forward(self, x):
        
        out = F.relu(self.conv1(x))
        out = F.max_pool2d(out, 2)
        out = F.relu(self.conv2(out))
        out = F.max_pool2d(out, 2)
        out = out.view(out.size(0), -1)
        out = F.relu(self.fc1(out))
        out = F.relu(self.fc2(out))
        out = self.fc3(out)
        return out

    ### Bonus Try to initialize the weights with Kaiming- Normal
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight)
    """
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * (m.in_channels + m.out_channels)
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                n = m.weight.size(1)
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_() """

# %%
# Specify the device for computation
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = LeNet5()
net = net.to(device)
if device =='cuda':
    print("Train on GPU...")
else:
    print("Train on CPU...")
# Initial learning rate
INITIAL_LR = 0.01
# Momentum for optimizer.
MOMENTUM = 0.9
# Regularization
REG = 1e-4
# Total number of training epochs
EPOCHS = 30
# Learning rate decay policy.
DECAY_EPOCHS = 2
DECAY = 1.00
CHECKPOINT_PATH = "./saved_model"
# FLAG for loading the pretrained model
TRAIN_FROM_SCRATCH = True
# Code for loading checkpoint and recover epoch id.
CKPT_PATH = "./saved_model/model.h5"
def get_checkpoint(ckpt_path):
    try:
        ckpt = torch.load(ckpt_path)
    except Exception as e:
        print(e)
        return None
    return ckpt

ckpt = get_checkpoint(CKPT_PATH)
if ckpt is None or TRAIN_FROM_SCRATCH:
    if not TRAIN_FROM_SCRATCH:
        print("Checkpoint not found.")
    print("Training from scratch ...")
    start_epoch = 0
    current_learning_rate = INITIAL_LR
else:
    print("Successfully loaded checkpoint: %s" %CKPT_PATH)
    net.load_state_dict(ckpt['net'])
    start_epoch = ckpt['epoch'] + 1
    current_learning_rate = ckpt['lr']
    print("Starting from epoch %d " %start_epoch)

print("Starting from learning rate %f:" %current_learning_rate)
# Create loss function and specify regularization
criterion = nn.CrossEntropyLoss()
# Add optimizer
optimizer = optim.SGD(params=net.parameters(), lr=current_learning_rate, momentum=MOMENTUM, weight_decay=REG, nesterov=False)
# Out:
# Train on GPU...
# Training from scratch ...
# Starting from learning rate 0.010000:

# %%
# Start the training/validation process
# The process should take about 5 minutes on a GTX 1070-Ti
# if the code is written efficiently.
list_train_k =[]
list_val_k =[]
global_step = 0
best_val_acc = 0

for i in range(start_epoch, EPOCHS):
#     print(datetime.datetime.now())
    # Switch to train mode
    net.train()
    print("Epoch %d:" %i)

    total_examples = 0
    correct_examples = 0

    train_loss = 0
    train_acc = 0
    
    # Train the training dataset for 1 epoch.
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        # Copy inputs to device
        inputs = inputs.to(device)
        targets = targets.to(device)
        # Zero the gradient
        optimizer.zero_grad()
        # Generate output
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        if (batch_idx == 0) & (i == start_epoch):
            print("INITIAL LOSS before traning: %.4f" %loss)
        # Now backward loss
        loss.backward()
        # Apply gradient
        optimizer.step()
        # Calculate predicted labels
        _, predicted = outputs.max(1)
        total_examples += predicted.size(0)
        correct_examples += predicted.eq(targets).sum().item()
        train_loss += loss
        global_step += 1
                
    avg_loss = train_loss / (batch_idx + 1)
    avg_acc = correct_examples / total_examples
    list_train.append(avg_acc)
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))
#     print(datetime.datetime.now())
    # Validate on the validation dataset
    print("Validation...")
    total_examples = 0
    correct_examples = 0
    
    net.eval()

    val_loss = 0
    val_acc = 0
    # Disable gradient during validation
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(valloader):
            # Copy inputs to device
            inputs = inputs.to(device)
            targets = targets.to(device)
            # Zero the gradient
            optimizer.zero_grad()
            # Generate output from the DNN.
            outputs = net(inputs)
            loss = criterion(outputs, targets)            
            # Calculate predicted labels
            _, predicted = outputs.max(1)
            total_examples += predicted.size(0)
            correct_examples += predicted.eq(targets).sum().item()
            val_loss += loss

    avg_loss = val_loss / len(valloader)
    avg_acc = correct_examples / total_examples
    list_val.append(avg_acc)
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))

    # Handle the learning rate scheduler.
    if i % DECAY_EPOCHS == 0 and i != 0:
        current_learning_rate = current_learning_rate * DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
        print("Current learning rate has decayed to %f" %current_learning_rate)
    
    # Save for checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_PATH):
            os.makedirs(CHECKPOINT_PATH)
        print("Saving ...")
        state = {'net': net.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_PATH, 'model.h5'))

print("Optimization finished.")
# Out:
# Epoch 0:
# INITIAL LOSS before traning: 2.3130
# Training loss: 1.8807, Training accuracy: 0.3062
# Validation...
# Validation loss: 1.5971, Validation accuracy: 0.4230
# Saving ...
# Epoch 1:
# Training loss: 1.4748, Training accuracy: 0.4656
# Validation...
# Validation loss: 1.3926, Validation accuracy: 0.5076
# Saving ...
# Epoch 2:
# Training loss: 1.3216, Training accuracy: 0.5237
# Validation...
# Validation loss: 1.2908, Validation accuracy: 0.5358
# Current learning rate has decayed to 0.010000
# Saving ...
# Epoch 3:
# Training loss: 1.2229, Training accuracy: 0.5627
# Validation...
# Validation loss: 1.1954, Validation accuracy: 0.5758
# Saving ...
# Epoch 4:
# Training loss: 1.1475, Training accuracy: 0.5941
# Validation...
# Validation loss: 1.1615, Validation accuracy: 0.5866
# Current learning rate has decayed to 0.010000
# Saving ...
# Epoch 5:
# Training loss: 1.0851, Training accuracy: 0.6149
# Validation...
# Validation loss: 1.1178, Validation accuracy: 0.6102
# Saving ...
# Epoch 6:
# Training loss: 1.0338, Training accuracy: 0.6372
# Validation...
# Validation loss: 1.1036, Validation accuracy: 0.6224
# Current learning rate has decayed to 0.010000
# Saving ...
# Epoch 7:
# Training loss: 0.9786, Training accuracy: 0.6548
# Validation...
# Validation loss: 1.0774, Validation accuracy: 0.6270
# Saving ...
# Epoch 8:
# Training loss: 0.9465, Training accuracy: 0.6672
# Validation...
# Validation loss: 1.0570, Validation accuracy: 0.6382
# Current learning rate has decayed to 0.010000
# Saving ...
# Epoch 9:
# Training loss: 0.9011, Training accuracy: 0.6854
# Validation...
# Validation loss: 1.0723, Validation accuracy: 0.6428
# Saving ...
# Epoch 10:
# Training loss: 0.8685, Training accuracy: 0.6920
# Validation...
# Validation loss: 1.1085, Validation accuracy: 0.6214
# Current learning rate has decayed to 0.010000
# Epoch 11:
# Training loss: 0.8214, Training accuracy: 0.7111
# Validation...
# Validation loss: 1.0957, Validation accuracy: 0.6246
# Epoch 12:
# Training loss: 0.7965, Training accuracy: 0.7181
# Validation...
# Validation loss: 1.2043, Validation accuracy: 0.6104
# Current learning rate has decayed to 0.010000
# Epoch 13:
# Training loss: 0.7658, Training accuracy: 0.7274
# Validation...
# Validation loss: 1.0991, Validation accuracy: 0.6426
# Epoch 14:
# Training loss: 0.7315, Training accuracy: 0.7407
# Validation...
# Validation loss: 1.1811, Validation accuracy: 0.6236
# Current learning rate has decayed to 0.010000
# Epoch 15:
# Training loss: 0.7108, Training accuracy: 0.7461
# Validation...
# Validation loss: 1.1127, Validation accuracy: 0.6432
# Saving ...
# Epoch 16:
# Training loss: 0.6832, Training accuracy: 0.7572
# Validation...
# Validation loss: 1.1740, Validation accuracy: 0.6360
# Current learning rate has decayed to 0.010000
# Epoch 17:
# Training loss: 0.6599, Training accuracy: 0.7664
# Validation...
# Validation loss: 1.1995, Validation accuracy: 0.6300
# Epoch 18:
# Training loss: 0.6499, Training accuracy: 0.7685
# Validation...
# Validation loss: 1.2245, Validation accuracy: 0.6154
# Current learning rate has decayed to 0.010000
# Epoch 19:
# Training loss: 0.6176, Training accuracy: 0.7802
# Validation...
# Validation loss: 1.2101, Validation accuracy: 0.6302
# Epoch 20:
# Training loss: 0.5939, Training accuracy: 0.7872
# Validation...
# Validation loss: 1.2657, Validation accuracy: 0.6292
# Current learning rate has decayed to 0.010000
# Epoch 21:
# Training loss: 0.5827, Training accuracy: 0.7904
# Validation...
# Validation loss: 1.3665, Validation accuracy: 0.6146
# Epoch 22:
# Training loss: 0.5661, Training accuracy: 0.7954
# Validation...
# Validation loss: 1.3221, Validation accuracy: 0.6138
# Current learning rate has decayed to 0.010000
# Epoch 23:
# Training loss: 0.5379, Training accuracy: 0.8059
# Validation...
# Validation loss: 1.4253, Validation accuracy: 0.6144
# Epoch 24:
# Training loss: 0.5379, Training accuracy: 0.8056
# Validation...
# Validation loss: 1.3624, Validation accuracy: 0.6250
# Current learning rate has decayed to 0.010000
# Epoch 25:
# Training loss: 0.5071, Training accuracy: 0.8199
# Validation...
# Validation loss: 1.4666, Validation accuracy: 0.6136
# Epoch 26:
# Training loss: 0.5027, Training accuracy: 0.8209
# Validation...
# Validation loss: 1.4318, Validation accuracy: 0.6176
# Current learning rate has decayed to 0.010000
# Epoch 27:
# Training loss: 0.4945, Training accuracy: 0.8214
# Validation...
# Validation loss: 1.4629, Validation accuracy: 0.6214
# Epoch 28:
# Training loss: 0.4695, Training accuracy: 0.8338
# Validation...
# Validation loss: 1.5246, Validation accuracy: 0.6132
# Current learning rate has decayed to 0.010000
# Epoch 29:
# Training loss: 0.4645, Training accuracy: 0.8341
# Validation...
# Validation loss: 1.5447, Validation accuracy: 0.6136
# Optimization finished.
